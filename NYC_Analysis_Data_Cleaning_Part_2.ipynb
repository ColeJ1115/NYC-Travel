# %% [markdown]
# <a href="https://colab.research.google.com/github/ColeJ1115/NYC-Travel/blob/main/NYC_Analysis_Data_Cleaning_Part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Day 2 of Data Cleaning**

# %%
import pandas as pd
import numpy as np

# %%
dbnb  = pd.read_csv('Airbnb_Cleaned.csv')

# %%
dbnb
# Out:
#        Unnamed: 0 neighbourhood_group        room_type  price  minimum_nights  \
# 0               0            Brooklyn     Private room    149               1
# 1               1           Manhattan  Entire home/apt    225               1
# 2               2           Manhattan     Private room    150               3
# 3               3            Brooklyn  Entire home/apt     89               1
# 4               4           Manhattan  Entire home/apt     80              10
# ...           ...                 ...              ...    ...             ...
# 48890       48890            Brooklyn     Private room     70               2
# 48891       48891            Brooklyn     Private room     40               4
# 48892       48892           Manhattan  Entire home/apt    115              10
# 48893       48893           Manhattan      Shared room     55               1
# 48894       48894           Manhattan     Private room     90               7
#
#        availability_365
# ...

# %%
dbnb.groupby('neighbourhood_group')['price'].mean()
# Out:
# neighbourhood_group
# Bronx             87.496792
# Brooklyn         124.383207
# Manhattan        196.875814
# Queens            99.517649
# Staten Island    114.812332
# Name: price, dtype: float64

# %%
dbnb.groupby('neighbourhood_group')['minimum_nights'].mean()
# Out:
# neighbourhood_group
# Bronx            4.560953
# Brooklyn         6.056556
# Manhattan        8.579151
# Queens           5.181433
# Staten Island    4.831099
# Name: minimum_nights, dtype: float64

# %%
dbnb['total_cost'] = dbnb['price'] * dbnb['minimum_nights']

# %%
dbnb.groupby('neighbourhood_group')['total_cost'].mean()
# Out:
# neighbourhood_group
# Bronx             346.841430
# Brooklyn          806.924343
# Manhattan        1890.080283
# Queens            893.319802
# Staten Island     533.378016
# Name: total_cost, dtype: float64

# %%
dair = dbnb.groupby('neighbourhood_group')

# %% [markdown]
# Grouping Airbnb dataset by "nieghborhood group" showcasing price, required minimum nights, and availability. Created "total_cost" column by multiplying price by minimum_nights columns. Can group by neighborhood to find average cost and minimum nights need for each neighborhood.

# %%
dair.head()
# Out:
#      Unnamed: 0 neighbourhood_group        room_type  price  minimum_nights  \
# 0             0            Brooklyn     Private room    149               1
# 1             1           Manhattan  Entire home/apt    225               1
# 2             2           Manhattan     Private room    150               3
# 3             3            Brooklyn  Entire home/apt     89               1
# 4             4           Manhattan  Entire home/apt     80              10
# 5             5           Manhattan  Entire home/apt    200               3
# 6             6            Brooklyn     Private room     60              45
# 7             7           Manhattan     Private room     79               2
# 12           12            Brooklyn     Private room     89               4
# 15           15            Brooklyn  Entire home/apt    140               2
# 46           46              Queens     Private room    130               3
# ...

# %%
dline = pd.read_csv('Airline_Cleaned.csv')

# %%
dline.head()
# Out:
#    Unnamed: 0  Age                          Airport Name Airport Country Code  \
# 0        1214   42  John F Kennedy International Airport                   US
# 1       10667   65                    La Guardia Airport                   US
# 2       11091   49                      Flushing Airport                   US
# 3       12102   65  John F Kennedy International Airport                   US
# 4       13269   16                      Flushing Airport                   US
#
#     Country Name Departure Date Arrival Airport  Month_Year
# 0  United States     2022-03-11             JFK  2022-03-01
# 1  United States     2022-12-18             LGA  2022-12-01
# 2  United States     2022-06-07             FLU  2022-06-01
# 3  United States     2022-10-15             JFK  2022-10-01
# 4  United States     2022-05-19             FLU  2022-05-01

# %%
dpop = pd.read_csv('Population_Cleaned.csv')

# %% [markdown]
# This data will display population in New York, New York. We can use this to compare any relationship with Airbnb prices. Fully filtered down

# %%
dpop.head()
# Out:
#    Unnamed: 0      NAME    STNAME  ESTIMATESBASE2020  POPESTIMATE2020  \
# 0       46169  New York  New York           20202320         20104710
#
#    POPESTIMATE2021  POPESTIMATE2022  POPESTIMATE2023
# 0         19854526         19673200         19571216

# %%
dweather = pd.read_csv('Weather_Cleaned.csv')

# %%
dweather.head()
# Out:
#    Unnamed: 0  Type  Severity       StartTime(UTC)         EndTime(UTC)  \
# 0     1003661   Fog  Moderate  2022-01-01 01:51:00  2022-01-01 02:51:00
# 1     1003662  Rain     Light  2022-01-01 08:51:00  2022-01-01 09:51:00
# 2     1003663  Rain     Light  2022-01-01 10:51:00  2022-01-01 19:51:00
# 3     1003664  Rain     Light  2022-01-01 21:51:00  2022-01-02 02:41:00
# 4     1003665  Rain  Moderate  2022-01-02 02:41:00  2022-01-02 04:22:00
#
#    Precipitation(in) AirportCode      City State
# 0               0.00        KNYC  New York    NY
# 1               0.00        KNYC  New York    NY
# 2               0.25        KNYC  New York    NY
# 3               0.47        KNYC  New York    NY
# 4               1.07        KNYC  New York    NY

# %%
dweather = dweather.drop(columns= ['EndTime(UTC)'])

# %%
import datetime as dt

# %%
dweather['Start_Time'] = pd.to_datetime(dweather['StartTime(UTC)']).dt.date

# %%
dweather.head()
# Out:
#    Unnamed: 0  Type  Severity       StartTime(UTC)  Precipitation(in)  \
# 0     1003661   Fog  Moderate  2022-01-01 01:51:00               0.00
# 1     1003662  Rain     Light  2022-01-01 08:51:00               0.00
# 2     1003663  Rain     Light  2022-01-01 10:51:00               0.25
# 3     1003664  Rain     Light  2022-01-01 21:51:00               0.47
# 4     1003665  Rain  Moderate  2022-01-02 02:41:00               1.07
#
#   AirportCode      City State  Start_Time
# 0        KNYC  New York    NY  2022-01-01
# 1        KNYC  New York    NY  2022-01-01
# 2        KNYC  New York    NY  2022-01-01
# 3        KNYC  New York    NY  2022-01-01
# 4        KNYC  New York    NY  2022-01-02

# %%
dweather = dweather.drop(columns= ['StartTime(UTC)'])

# %%
dweather.groupby('Start_Time')['Severity'].count()
# Out:
# Start_Time
# 2022-01-01     8
# 2022-01-02    14
# 2022-01-05     8
# 2022-01-07    22
# 2022-01-09     4
#               ..
# 2022-12-16     8
# 2022-12-22     4
# 2022-12-23    20
# 2022-12-28     2
# 2022-12-31    14
# Name: Severity, Length: 157, dtype: int64

# %%
dweather['Month'] = pd.DatetimeIndex(dweather['Start_Time']).month

# %% [markdown]
# Filtering weather data most common weather types by month

# %%
dweather.groupby('Month')['Type'].max()
# Out:
# Month
# 1     Snow
# 2     Snow
# 3     Snow
# 4     Rain
# 5     Rain
# 6     Rain
# 7     Rain
# 8     Rain
# 9     Rain
# 10    Rain
# 11    Rain
# 12    Snow
# Name: Type, dtype: object

# %% [markdown]
# Total sum of precipitation in inches by month

# %%
dweather.groupby('Month')['Precipitation(in)'].sum()
# Out:
# Month
# 1     15.18
# 2      7.60
# 3     11.20
# 4     17.56
# 5     18.32
# 6     15.26
# 7     29.88
# 8      9.24
# 9     19.32
# 10    21.80
# 11    15.20
# 12    25.66
# Name: Precipitation(in), dtype: float64

# %%
dweather.to_csv('Weather_Grouped.csv')

# %%
dhotel = pd.read_csv('Hotel Prices.csv')

# %%
dhotel.head()
# Out:
#          Series ID  Year Period     Label    Value  1-Month % Change
# 0  PCU721110721110  2022    M01  2022 Jan  152.252              -1.9
# 1  PCU721110721110  2022    M02  2022 Feb  154.947               1.8
# 2  PCU721110721110  2022    M03  2022 Mar  173.270              11.8
# 3  PCU721110721110  2022    M04  2022 Apr  165.921              -4.2
# 4  PCU721110721110  2022    M05  2022 May  162.905              -1.8

# %%
dhotel.groupby('Period')['Value'].mean()
# Out:
# Period
# M01    159.784667
# M02    162.083667
# M03    174.155667
# M04    171.348000
# M05    167.523333
# M06    178.477000
# M07    180.035000
# M08    173.212000
# M09    168.236500
# M10    170.427500
# M11    167.556000
# M12    167.209500
# Name: Value, dtype: float64

# %% [markdown]
# NYC has an averaged 8% price increase over the national average from online research. This column creates an estimate of NYC price.

# %%
dhotel['NYC Avg'] = dhotel['Value'] * 1.08

# %%
dhotel.head()
# Out:
#          Series ID  Year Period     Label    Value  1-Month % Change  \
# 0  PCU721110721110  2022    M01  2022 Jan  152.252              -1.9
# 1  PCU721110721110  2022    M02  2022 Feb  154.947               1.8
# 2  PCU721110721110  2022    M03  2022 Mar  173.270              11.8
# 3  PCU721110721110  2022    M04  2022 Apr  165.921              -4.2
# 4  PCU721110721110  2022    M05  2022 May  162.905              -1.8
#
#      NYC Avg
# 0  164.43216
# 1  167.34276
# 2  187.13160
# 3  179.19468
# 4  175.93740

# %%
dhotel.to_csv('Hotel_Grouped.csv')
